# %% [markdown]
# #RAG (retrieval augmented generation )  How to use Azure Cosmos DB for Mongo DB v-Core as vector database
# <img src='
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="771px" height="561px" viewBox="-0.5 -0.5 771 561" class="ge-export-svg-dark" content="&lt;mxfile host=&quot;app.diagrams.net&quot; modified=&quot;2024-03-23T22:45:22.927Z&quot; agent=&quot;Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36&quot; etag=&quot;FH8c-75i-WGS9w98_Z83&quot; version=&quot;24.1.0&quot; type=&quot;onedrive&quot; scale=&quot;1&quot; border=&quot;0&quot;&gt;&#10;  &lt;diagram name=&quot;Page-1&quot; id=&quot;uMh5ziSSKN0f_kxXhH-7&quot;&gt;&#10;    &lt;mxGraphModel dx=&quot;956&quot; dy=&quot;572&quot; grid=&quot;1&quot; gridSize=&quot;10&quot; guides=&quot;1&quot; tooltips=&quot;1&quot; connect=&quot;1&quot; arrows=&quot;1&quot; fold=&quot;1&quot; page=&quot;1&quot; pageScale=&quot;1&quot; pageWidth=&quot;850&quot; pageHeight=&quot;1100&quot; math=&quot;0&quot; shadow=&quot;0&quot;&gt;&#10;      &lt;root&gt;&#10;        &lt;mxCell id=&quot;0&quot; /&gt;&#10;        &lt;mxCell id=&quot;1&quot; parent=&quot;0&quot; /&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-5&quot; value=&quot;&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-1&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-2&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-1&quot; value=&quot;Chat History&quot; style=&quot;rounded=1;whiteSpace=wrap;html=1;labelBackgroundColor=none;fillColor=#5D7F99;strokeColor=#D0CEE2;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;30&quot; y=&quot;410&quot; width=&quot;100&quot; height=&quot;30&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-7&quot; value=&quot;&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-2&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-6&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-2&quot; value=&quot;User Question from AI UX&quot; style=&quot;rounded=1;whiteSpace=wrap;html=1;labelBackgroundColor=none;fillColor=#5D7F99;strokeColor=#D0CEE2;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;80&quot; y=&quot;300&quot; width=&quot;120&quot; height=&quot;60&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-11&quot; value=&quot;&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-6&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-13&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot;&gt;&#10;            &lt;mxPoint x=&quot;340&quot; y=&quot;440&quot; as=&quot;targetPoint&quot; /&gt;&#10;          &lt;/mxGeometry&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-60&quot; value=&quot;&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-6&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-59&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-6&quot; value=&quot;Prompt just with Question&amp;amp;nbsp;&quot; style=&quot;whiteSpace=wrap;html=1;rounded=1;labelBackgroundColor=none;fillColor=#5D7F99;strokeColor=#D0CEE2;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;280&quot; y=&quot;300&quot; width=&quot;120&quot; height=&quot;60&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-64&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-13&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-52&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-13&quot; value=&quot;Embedding Models&amp;lt;div&amp;gt;Open AI Ada&amp;lt;/div&amp;gt;&quot; style=&quot;shape=cube;whiteSpace=wrap;html=1;boundedLbl=1;backgroundOutline=1;darkOpacity=0.05;darkOpacity2=0.1;labelBackgroundColor=none;fillColor=#5D7F99;strokeColor=#D0CEE2;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;190&quot; y=&quot;447.98&quot; width=&quot;180&quot; height=&quot;80&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-21&quot; value=&quot;&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-19&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-20&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot;&gt;&#10;            &lt;mxPoint x=&quot;150&quot; y=&quot;645&quot; as=&quot;sourcePoint&quot; /&gt;&#10;          &lt;/mxGeometry&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-19&quot; value=&quot;&amp;lt;span style=&amp;quot;color: rgb(0, 0, 0); text-wrap: wrap;&amp;quot;&amp;gt;PDF and unstructured documents&amp;amp;nbsp;&amp;lt;/span&amp;gt;&quot; style=&quot;outlineConnect=0;fontColor=#1A1A1A;fillColor=#5D7F99;strokeColor=none;dashed=0;verticalLabelPosition=bottom;verticalAlign=top;align=center;html=1;fontSize=12;fontStyle=0;aspect=fixed;pointerEvents=1;shape=mxgraph.aws4.documents;labelBackgroundColor=none;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot
gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-67&quot; value=&quot;LLM&amp;lt;div&amp;gt;GPT 3.5/4&amp;lt;/div&amp;gt;&quot; style=&quot;outlineConnect=0;fontColor=#1A1A1A;fillColor=#5D7F99;strokeColor=none;dashed=0;verticalLabelPosition=bottom;verticalAlign=top;align=center;html=1;fontSize=12;fontStyle=0;aspect=fixed;pointerEvents=1;shape=mxgraph.aws4.sagemaker_model;labelBackgroundColor=none;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;690&quot; y=&quot;300&quot; width=&quot;78&quot; height=&quot;78&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-68&quot; style=&quot;edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;entryX=0.55;entryY=0.989;entryDx=0;entryDy=0;entryPerimeter=0;flowAnimation=1;labelBackgroundColor=none;strokeColor=#736CA8;fontColor=default;&quot; edge=&quot;1&quot; parent=&quot;1&quot; source=&quot;2yY4hUrRj8moL_Lnh8qQ-52&quot; target=&quot;2yY4hUrRj8moL_Lnh8qQ-59&quot;&gt;&#10;          &lt;mxGeometry relative=&quot;1&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-74&quot; value=&quot;&quot; style=&quot;swimlane;startSize=0;labelBackgroundColor=none;fillColor=#5D7F99;strokeColor=#D0CEE2;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;20&quot; y=&quot;610&quot; width=&quot;770&quot; height=&quot;140&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-75&quot; value=&quot;RAG pipeline&quot; style=&quot;text;strokeColor=none;align=center;fillColor=none;html=1;verticalAlign=middle;whiteSpace=wrap;rounded=0;labelBackgroundColor=none;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;2yY4hUrRj8moL_Lnh8qQ-74&quot;&gt;&#10;          &lt;mxGeometry x=&quot;284&quot; y=&quot;100&quot; width=&quot;120&quot; height=&quot;30&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;        &lt;mxCell id=&quot;2yY4hUrRj8moL_Lnh8qQ-76&quot; value=&quot;&amp;lt;span style=&amp;quot;font-size: 51px; font-family: &amp;amp;quot;Aptos Display&amp;amp;quot;; color: black;&amp;quot;&amp;gt;RAG Process&amp;lt;br&amp;gt;&amp;lt;br&amp;gt;&amp;lt;/span&amp;gt;&quot; style=&quot;text;whiteSpace=wrap;html=1;labelBackgroundColor=none;fontColor=#1A1A1A;&quot; vertex=&quot;1&quot; parent=&quot;1&quot;&gt;&#10;          &lt;mxGeometry x=&quot;240&quot; y=&quot;190&quot; width=&quot;505&quot; height=&quot;100&quot; as=&quot;geometry&quot; /&gt;&#10;        &lt;/mxCell&gt;&#10;      &lt;/root&gt;&#10;    &lt;/mxGraphModel&gt;&#10;  &lt;/diagram&gt;&#10;&lt;/mxfile&gt;&#10;" style="background-color: rgb(0, 0, 0);"><defs><style>@keyframes ge-flow-animation-ZHfqIIlSKUuraW5kcL8N {&#xa;  to {&#xa;    stroke-dashoffset: 0;&#xa;  }&#xa;}</style><style type="text/css">svg.ge-export-svg-dark { filter: invert(100%) hue-rotate(180deg); }&#xa;svg.ge-export-svg-dark foreignObject img,&#xa;svg.ge-export-svg-dark image:not(svg.ge-export-svg-dark switch image),&#xa;svg.ge-export-svg-dark svg { filter: invert(100%) hue-rotate(180deg) }</style><style type="text/css">@font-face { font-family: "Architects Daughter"; src: url("data:application/x-font-ttf;charset=utf-8;base64,...") format("truetype"); }&#xa;</style></defs><rect fill="#ffffff" width="100%" height="100%" x="0" y="0"/><g><g><path d="M 60 220 L 60 195 L 120 195 L 120 176.37" fill="none" stroke="#736ca8" stroke-miterlimit="10" pointer-events="stroke" stroke-dasharray="8" style="animation: 500ms linear 0s infinite normal none running ge-flow-animation-ZHfqIIlSKUuraW5kcL8N; stroke-dashoffset: 16;"/><path d="M
.28 671.2 159.59 L 679.76 164.3 L 679.76 175.17 C 679.76 175.79 680.09 176.37 680.63 176.69 L 699.2 187.67 C 699.75 188 700.44 188 701 187.67 L 708.42 183.25 L 716.07 187.68 C 716.34 187.84 716.65 187.92 716.95 187.92 C 717.26 187.92 717.57 187.84 717.85 187.67 L 736.42 176.69 C 736.96 176.37 737.29 175.8 737.29 175.17 L 737.29 164.29 L 746.81 158.93 C 747.37 158.62 747.71 158.03 747.71 157.39 Z" fill="#5d7f99" stroke="none" pointer-events="all"/></g><g><g transform="translate(-0.5 -0.5)"><switch><foreignObject pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility" style="overflow: visible; text-align: left;"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe flex-start; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 195px; margin-left: 709px;"><div data-drawio-colors="color: #1A1A1A; " style="box-sizing: border-box; font-size: 0px; text-align: center;"><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: rgb(26, 26, 26); line-height: 1.2; pointer-events: all; white-space: nowrap;">LLM<div>GPT 3.5/4</div></div></div></div></foreignObject><image x="682" y="195.5" width="54" height="32" xlink:href="data:image/png;base64,..."/></switch></g></g><g><path d="M 556.25 267.98 L 556.27 219 L 526 219 L 526 175.71" fill="none" stroke="#736ca8" stroke-miterlimit="10" pointer-events="stroke" stroke-dasharray="8" style="animation: 500ms linear 0s infinite normal none running ge-flow-animation-ZHfqIIlSKUuraW5kcL8N; stroke-dashoffset: 16;"/><path d="M 526 170.46 L 529.5 177.46 L 526 175.71 L 522.5 177.46 Z" fill="#736ca8" stroke="#736ca8" stroke-miterlimit="10" pointer-events="all"/></g><g><path d="M 0 420 L 0 420 L 770 420 L 770 420" fill="#5d7f99" stroke="#d0cee2" stroke-miterlimit="10" pointer-events="all"/><path d="M 0 420 L 0 560 L 770 560 L 770 420" fill="none" stroke="#d0cee2" stroke-miterlimit="10" pointer-events="none"/></g><g><rect x="284" y="520" width="120" height="30" fill="none" stroke="none" pointer-events="all"/></g><g><g transform="translate(-0.5 -0.5)"><switch><foreignObject pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility" style="overflow: visible; text-align: left;"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 535px; margin-left: 285px;"><div data-drawio-colors="color: #1A1A1A; " style="box-sizing: border-box; font-size: 0px; text-align: center;"><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: rgb(26, 26, 26); line-height: 1.2; pointer-events: all; white-space: normal; overflow-wrap: normal;">RAG pipeline</div></div></div></foreignObject><image x="285" y="528.5" width="118" height="17" xlink:href="data:image/png;base64,..."/></switch></g></g><g><rect x="220" y="0" width="505" height="100" fill="none" stroke="none" pointer-events="all"/></g><g><g transform="translate(-0.5 -0.5)"><switch><foreignObject pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility" style="overflow: visible; text-align: left;"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe flex-start; justify-content: unsafe flex-start; width: 503px; height: 1px; padding-top: 7px; margin-left: 222px;"><div data-drawio-colors="color: #1A1A1A; " style="box-sizing: border-box; font-size: 0px; text-align: left;"><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: rgb(26, 26, 26); line-height: 1.2; pointer-events: all; white-space: normal; overflow-wrap: normal;"><span style="font-size: 51px; font-family: &quot;Aptos Display&quot;; color: black;">RAG Process<br /><br /></span></div></div></div></foreignObject><image x="222" y="7.5" width="503" height="125" xlink:href="data:image/png;base64,..."/></switch></g></g></g></svg>'>

# %% [markdown]
# # Preliminaries <a class="anchor" id="preliminaries"></a>
# First, let's start by installing the packages that we'll need later.

# %%
! pip install numpy
! pip install openai 
! pip install pymongo
! pip install python-dotenv
! pip install azure-core
! pip install azure-cosmos
! pip install tenacity
! pip install pypdf
! install langchain
! pip install unstructured
! pip install langchain

# %%
import json
import datetime
import time

from azure.core.exceptions import AzureError
from azure.core.credentials import AzureKeyCredential
import pymongo

import openai
from dotenv import load_dotenv
from tenacity import retry, wait_random_exponential, stop_after_attempt
from openai import AzureOpenAI

# %%
import langchain

# %%
from langchain.document_loaders import PyPDFLoader, OnlinePDFLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# Please use the example.env as a template to provide the necessary keys and endpoints in your own .env file.
# Make sure to modify the env_name accordingly.

# %%
print(openai.VERSION) #should be greater than 1.0xx
# Out:
# 1.13.3

# %%
from dotenv import dotenv_values

# specify the name of the .env file name 
env_name = "example.env" # following example.env template change to your own .env file name
config = dotenv_values(env_name)

cosmosdb_endpoint = config['cosmos_db_api_endpoint']
cosmosdb_key = config['cosmos_db_api_key']
cosmosdb_connection_str = config['cosmos_db_connection_string']

COSMOS_MONGO_USER = config['cosmos_db_mongo_user']
COSMOS_MONGO_PWD = config['cosmos_db_mongo_pwd']
COSMOS_MONGO_SERVER = config['cosmos_db_mongo_server']

openai.api_type = config['openai_api_type']
openai.api_key = config['openai_api_key']
openai.api_base = config['openai_api_endpoint']
openai.api_version = config['openai_api_version']
embeddings_deployment = config['openai_embeddings_deployment']
completions_deployment = config['openai_completions_deployment']

# %% [markdown]
# ## Create an Azure Cosmos DB for MongoDB vCore resource<a class="anchor" id="cosmosdb"></a>
# Let's start by creating an Azure Cosmos DB for MongoDB vCore Resource following this quick start guide: https://learn.microsoft.com/en-us/azure/cosmos-db/mongodb/vcore/quickstart-portal
#
# Then copy the connection details (server, user, pwd) into the config.json file.

# %% [markdown]
# ## Azure OpenAI <a class="anchor" id="azureopenai"></a>
#
# Finally, let's setup our Azure OpenAI resource Currently, access to this service is granted only by application. You can apply for access to Azure OpenAI by completing the form at https://aka.ms/oai/access. Once you have access, complete the following steps:
#
# - Create an Azure OpenAI resource following this quickstart: https://learn.microsoft.com/azure/ai-services/openai/how-to/create-resource?pivots=web-portal
# - Deploy a `completions` and `embeddings` model
#     - For more information on `completions`, go here: https://learn.microsoft.com/azure/ai-services/openai/how-to/completions
#     - For more information on `embeddings`, go here: https://learn.microsoft.com/azure/ai-services/openai/how-to/embeddings
# - Copy the endpoint, key, deployment names for (embeddings model, completions model) into the config.json file.

# %% [markdown]
# # Load data and create embeddings <a class="anchor" id="loaddata"></a>
# Here we load a sample dataset containing descriptions of Azure services, then we use Azure OpenAI to create vector embeddings from this data.

# %%
loader = PyPDFLoader("./investmentbanking.pdf.pdf")

# %% [markdown]
# # Step  Split the Text into Chunks

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=600, chunk_overlap=0)
data = loader.load()
docs=text_splitter.split_documents(data)
len(docs)
# Out:
# 82

# %%
docs[5]
# Out:
# Document(page_content='believe it or not, religious leaders. If you ’ re interested in the very early days \nof investment banking, check out the appendix for a quick history lesson. \n But for now, just know that investment banking is, at its very core, pretty \nstraightforward. Investment banking is a method of controlling the flow of \nmoney. The goal of investment banking is channeling cash from investors \nlooking for returns into the hands of entrepreneurs and business builders \nwho are long on ideas, but short on bucks. \n    Investment bankers raise money from investors, by selling securities, and', metadata={'source': './investmentbanking.pdf.pdf', 'page': 1})

# %% [markdown]
# # Creating Open AI Client for Library 1.xx

# %%
client = AzureOpenAI(
  api_key =config['openai_api_key'],  
  api_version = "2023-05-15",
  azure_endpoint =config['openai_api_endpoint']
)

# %% [markdown]
# # Create Embedding with Open AI Model

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(20))
def generate_embeddings(text):
    '''
    Generate embeddings from string of text.
    This will be used to vectorize data and user input for interactions with Azure OpenAI.
    '''
   
   
    embeddings = client.embeddings.create(input = text, model="myembeddingmodel").data[0].embedding 
    time.sleep(0.2) # rest period to avoid rate limiting on AOAI for free tier
    return embeddings

# %%
docs

# %%
datax = generate_embeddings(docs[0].page_content)

# %%
print(datax)
# Out:
# [0.0019286874448880553, -0.02175409160554409, 0.018986299633979797, 0.0016891669947654009, -0.026726098731160164, 0.007251364178955555, -0.009956535883247852, -0.01153455302119255, -0.011077429167926311, -0.035593051463365555, 0.009299028664827347, 0.016544131562113762, -0.03313835710287094, 0.008203184232115746, 0.007119862362742424, -0.0028726798482239246, 0.014991161413490772, -0.012837043032050133, -0.001018353272229433, -0.005570024251937866, -0.044485051184892654, 0.006531237158924341, -0.01214196439832449, -0.012849567458033562, 0.0027724881656467915, -0.0021040227729827166, 0.017345663160085678, -0.027302199974656105, 0.014302344992756844, 0.011027333326637745, -0.014991161413490772, 0.003080890513956547, -0.002612808020785451, 0.00835347082465887, -0.0004958699573762715, -0.016068220138549805, -0.006412259768694639, -0.02071460522711277, 0.017095183953642845, -0.01250515878200531, 0.021854283288121223, 0.014966113492846489, -0.01894872821867466, 0.0074580092914402485, -0.014
# ...

# %%
embeddingslist = []  # Initialize an empty list to store embeddings

# Loop through each item in the docs array
for item in docs:
   # Generate embeddings for the current item (replace with your actual logic)
   content_embeddings = generate_embeddings(item.page_content)

   # Create a dictionary to store the content and its embeddings
   embedd_dict = {"content": item.page_content, "contentVector": content_embeddings}

   # Add the dictionary to the embeddlist
   embeddingslist.append(embedd_dict)

# %%
embeddingslist[0]
# Out:
# {'content': 'Chapter  1                  \n Introducing Investment Banking        \n In This Chapter \n      ▶      Understanding what investment banking is  \n    ▶      Recognizing the critical role investment banking plays in the capital formation process  \n    ▶      Discovering how investment banking compares with traditional banking  \n    ▶      Finding out how investment banking operations make their money  \n    ▶      Looking at the different types of investment banks and what they do',
#  'contentVector': [0.0019286874448880553,
#   -0.02175409160554409,
#   0.018986299633979797,
#   0.0016891669947654009,
#   -0.026726098731160164,
#   0.007251364178955555,
#   -0.009956535883247852,
#   -0.01153455302119255,
#   -0.011077429167926311,
#   -0.035593051463365555,
#   0.009299028664827347,
#   0.016544131562113762,
#   -0.03313835710287094,
#   0.008203184232115746,
#   0.007119862362742424,
#   -0.0028726798482239246,
#   0.014991161413490772,
#   -0.012837043032050133,
# ...

# %% [markdown]
# # Connect and setup Cosmos DB for MongoDB vCore

# %% [markdown]
# ## Set up the connection

# %%
mongo_conn = "mongodb+srv://"+COSMOS_MONGO_USER+":"+COSMOS_MONGO_PWD+"@"+COSMOS_MONGO_SERVER+"?tls=true&authMechanism=SCRAM-SHA-256&retrywrites=false&maxIdleTimeMS=120000"

# %% [markdown]
# ##  Set up the DB and collection

# %%
# create a database called TutorialDB
db = mongo_client['ExampleDB']

# Create collection if it doesn't exist
COLLECTION_NAME = "InvestmentCollection"

collection = db[COLLECTION_NAME]

if COLLECTION_NAME not in db.list_collection_names():
    # Creates a unsharded collection that uses the DBs shared throughput
    db.create_collection(COLLECTION_NAME)
    print("Created collection '{}'.\n".format(COLLECTION_NAME))
else:
    print("Using collection: '{}'.\n".format(COLLECTION_NAME))
# Out:
# Using collection: 'InvestmentCollection'.

# %%
## Use only if re-reunning code and want to reset db and collection
collection.drop_index("VectorSearchIndex")
mongo_client.drop_database("ExampleDB")

# %% [markdown]
# ## Create the vector index
#
# **IMPORTANT: You can only create one index per vector property.** That is, you cannot create more than one index that points to the same vector property. If you want to change the index type (e.g., from IVF to HNSW) you must drop the index first before creating a new index.

# %% [markdown]
# ### IVF
# IVF is the default vector indexing algorithm, which works on all cluster tiers. It's an approximate nerarest neighbors (ANN) approach that uses clustering to speeding up the search for similar vectors in a dataset.

# %%
db.command({
  'createIndexes': 'InvestmentCollection',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 2,
#    'numIndexesAfter': 2,
#    'createdCollectionAutomatically': False,
#    'note': 'all indexes already exist',
#    'ok': 1}},
#  'ok': 1}

# %% [markdown]
# ## Upload data to the collection
# A simple `insert_many()` to insert our data in JSON format into the newly created DB and collection.

# %%
collection.insert_many(embeddingslist)
# Out:
# InsertManyResult([ObjectId('65ff8fd4eb66ea3f3a5b36d5'), ObjectId('65ff8fd4eb66ea3f3a5b36d6'), ObjectId('65ff8fd4eb66ea3f3a5b36d7'), ObjectId('65ff8fd4eb66ea3f3a5b36d8'), ObjectId('65ff8fd4eb66ea3f3a5b36d9'), ObjectId('65ff8fd4eb66ea3f3a5b36da'), ObjectId('65ff8fd4eb66ea3f3a5b36db'), ObjectId('65ff8fd4eb66ea3f3a5b36dc'), ObjectId('65ff8fd4eb66ea3f3a5b36dd'), ObjectId('65ff8fd4eb66ea3f3a5b36de'), ObjectId('65ff8fd4eb66ea3f3a5b36df'), ObjectId('65ff8fd4eb66ea3f3a5b36e0'), ObjectId('65ff8fd4eb66ea3f3a5b36e1'), ObjectId('65ff8fd4eb66ea3f3a5b36e2'), ObjectId('65ff8fd4eb66ea3f3a5b36e3'), ObjectId('65ff8fd4eb66ea3f3a5b36e4'), ObjectId('65ff8fd4eb66ea3f3a5b36e5'), ObjectId('65ff8fd4eb66ea3f3a5b36e6'), ObjectId('65ff8fd4eb66ea3f3a5b36e7'), ObjectId('65ff8fd4eb66ea3f3a5b36e8'), ObjectId('65ff8fd4eb66ea3f3a5b36e9'), ObjectId('65ff8fd4eb66ea3f3a5b36ea'), ObjectId('65ff8fd4eb66ea3f3a5b36eb'), ObjectId('65ff8fd4eb66ea3f3a5b36ec'), ObjectId('65ff8fd4eb66ea3f3a5b36ed'), ObjectId('65ff8fd4eb66ea3f3a5b
# ...

# %% [markdown]
# # Vector Search in Cosmos DB for MongoDB vCore

# %%
# Simple function to assist with vector search
def vector_search(query, num_results=5):
    query_embedding = generate_embeddings(query)
    embeddings_list = []
    pipeline = [
        {
            '$search': {
                "cosmosSearch": {
                    "vector": query_embedding,
                    "path": "contentVector",
                    "k": num_results #, "efsearch": 40 # optional for HNSW only 
                },
                "returnStoredSource": True }},
        {'$project': { 'similarityScore': { '$meta': 'searchScore' }, 'document' : '$$ROOT' } }
    ]
    results = collection.aggregate(pipeline)
    return results

# %% [markdown]
# Let's run a test query below.

# %%
query = "what was the revenue of JPMorgan Chase in 2012 ?"
results = vector_search(query ,10)
for result in results: 
#     print(result)
    print(f"Similarity Score: {result['similarityScore']}")  
    print(f"Title: {result['document']['content']}")
# Out:
# Similarity Score: 0.8244290178972862
# Title: 17  Chapter 1: Introducing Investment Banking
#  Business Unit  2012 Revenue
# ($ millions)  2011 Revenue
# ($ millions)  2010 Revenue
# ($ millions)
#  Institutional client
# services  18,124  17,280  21,796
#  Investing and
# lending  5,891  2,142  7,541
#  Investment
#  management  5,222  5,034  5,014
#  Investment
#  banking  4,926  4,355  4,810
#    Source: Goldman Sachs 2012 annual report
# ( www.sec.gov/Archives/edgar/data/886982/000119312513085474/
# d446679d10k.htm  )                 ✓       Investment banking:  This part of Goldman is the one most interesting to readers of this book.
# Similarity Score: 0.8118258974240965
# Title: system was comprised of behemoth banks that have the deposit-taking abili-
# ties of banks but also engage in investment banking. The result is the forma-
# tion of several mega-institutions that many people fear are “too big to fail,”
# including the ones shown in Table  1-1 .
# ...

# %% [markdown]
# # Q&A over the data with GPT-3.5
#
# Finally, we'll create a helper function to feed prompts into the `Completions` model. Then we'll create interactive loop where you can pose questions to the model and receive information grounded in your data.

# %%
#This function helps to ground the model with prompts and system instructions.
def generate_completion(prompt):
    system_prompt = '''
    You are an intelligent assistant for Investment Banking.
    ''' 
    listmessages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt},
    ]

    
    results = vector_search(prompt ,10)
    for item in results:
        listmessages.append({"role": "system", "content": item['document']['content']})
       
    
            
    response = client.chat.completions.create(
    model="gpt4livedemo", # model = "deployment_name".
    messages=listmessages
)
    
    return response.choices[0].message.content

# %%
system_prompt = '''
    You are an intelligent assistant.
    ''' 
  
listmessages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": "what was the revenue of  JPMorgan  Chase  in 2012?"},
    ]



response =client.chat.completions.create(
    model="gpt4livedemo", # model = "deployment_name".
    messages=listmessages
)

print(response.choices[0].message.content)
# Out:
# I'm sorry, but I don't have real-time access to historical financial data. Please refer to JPMorgan Chase's annual reports or trustworthy financial databases for the most accurate information.

# %%
generate_completion("what was the revenue of  JPMorgan  Chase  in 2012?")  # test Qustion with out RAG
# Out:
# 'The revenue of JPMorgan Chase in 2012 was $91.7 billion.'
